# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("chipotle.tsv",sep='\t')
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
data.shape
# Out:
# (4622, 5)

# %%
data.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
data['item_price'] = data['item_price'].str.replace('[$]', '', regex=True)

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN      2.39
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
data['item_price'] = pd.to_numeric(data['item_price'], errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 180.7+ KB

# %%
aggregated_data = grouped_data.agg({
    'quantity': sum,  # Sum the quantities for each order ID
    'item_name': lambda x: ', '.join(x),  # Concatenate item names for each order ID
    'choice_description': lambda x: ', '.join(map(str, x)),  # Concatenate choice descriptions for each order ID
    'item_price': 'sum'  # Sum the item prices for each order ID
})

# %%
aggregated_data = aggregated_data.reset_index()

# %%
aggregated_data['item_price'] = aggregated_data['item_price'].astype(str)

# %%
# Check for duplicates in the order ID column
duplicates = aggregated_data[aggregated_data.duplicated('order_id')]

# %%
# Export data to a new CSV file
aggregated_data.to_csv('Cleaned_data.csv', index=False)

# %%
Cleaned_data = pd.read_csv('Cleaned_data.csv')
Cleaned_data
# Out:
#       order_id  quantity                                          item_name  \
# 0            1         4  Chips and Fresh Tomato Salsa, Izze, Nantucket ...
# 1            2         2                                       Chicken Bowl
# 2            3         2                        Chicken Bowl, Side of Chips
# 3            4         2                    Steak Burrito, Steak Soft Tacos
# 4            5         2                 Steak Burrito, Chips and Guacamole
# ...        ...       ...                                                ...
# 1829      1830         2                      Steak Burrito, Veggie Burrito
# 1830      1831         3                Carnitas Bowl, Chips, Bottled Water
# 1831      1832         2            Chicken Soft Tacos, Chips and Guacamole
# 1832      1833         2                       Steak Burrito, Steak Burrito
# 1833      1834         3  Chicken Salad Bowl, Chicken Salad Bowl, Chicke...
#
# ...
